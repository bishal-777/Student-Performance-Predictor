# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("./final.csv")
df.head(5)
# Out:
#              Name  Attendance (%)  Study Hours/Week  Previous Score  \
# 0      Jane Smith           68.73             15.44           83.71
# 1     Chris Jones           97.54             13.50           67.65
# 2  Emily Williams           86.60             15.46           71.73
# 3      Jane Moore           79.93              5.06           67.09
# 4     Jane Taylor           57.80             13.90           50.74
#
#   Extracurricular Activities  Final Score
# 0                        Low        65.07
# 1                       High        56.83
# 2                        Low        61.53
# 3                       High        56.21
# 4                       High        37.17

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head(5)
# Out:
#              name  attendance_(%)  study_hours/week  previous_score  \
# 0      Jane Smith           68.73             15.44           83.71
# 1     Chris Jones           97.54             13.50           67.65
# 2  Emily Williams           86.60             15.46           71.73
# 3      Jane Moore           79.93              5.06           67.09
# 4     Jane Taylor           57.80             13.90           50.74
#
#   extracurricular_activities  final_score
# 0                        Low        65.07
# 1                       High        56.83
# 2                        Low        61.53
# 3                       High        56.21
# 4                       High        37.17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        324 non-null    object
#  1   attendance_(%)              324 non-null    float64
#  2   study_hours/week            324 non-null    float64
#  3   previous_score              324 non-null    float64
#  4   extracurricular_activities  324 non-null    object
#  5   final_score                 324 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 15.3+ KB

# %%
print(df.isnull().sum())
# Out:
# name                          0
# attendance_(%)                0
# study_hours/week              0
# previous_score                0
# extracurricular_activities    0
# final_score                   0
# dtype: int64

# %%
label_encoder = LabelEncoder()
df['extracurricular_activities'] = label_encoder.fit_transform(df['extracurricular_activities'])
df.head(5)
# Out:
#              name  attendance_(%)  study_hours/week  previous_score  \
# 0      Jane Smith           68.73             15.44           83.71
# 1     Chris Jones           97.54             13.50           67.65
# 2  Emily Williams           86.60             15.46           71.73
# 3      Jane Moore           79.93              5.06           67.09
# 4     Jane Taylor           57.80             13.90           50.74
#
#    extracurricular_activities  final_score
# 0                           1        65.07
# 1                           0        56.83
# 2                           1        61.53
# 3                           0        56.21
# 4                           0        37.17

# %%
df.describe()
# Out:
#        attendance_(%)  study_hours/week  previous_score  \
# count      324.000000        324.000000      324.000000
# mean        72.470185         15.413642       73.908796
# std         13.273268          3.109443       12.122704
# min         50.280000          5.060000       40.850000
# 25%         60.635000         13.497500       65.927500
# 50%         69.030000         15.340000       75.865000
# 75%         85.880000         17.235000       82.977500
# max         99.340000         27.320000       94.450000
#
#        extracurricular_activities  final_score
# count                  324.000000   324.000000
# mean                     1.040123    56.284599
# std                      0.841049     8.773223
# min                      0.000000    28.560000
# 25%                      0.000000    50.130000
# 50%                      1.000000    56.315000
# 75%                      2.000000    62.675000
# max                      2.000000    74.530000
