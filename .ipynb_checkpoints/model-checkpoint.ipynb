# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./xyz.csv")
df.head(5)
# Out:
#              Name  Attendance (%) Study Hours/Week  Previous Score  \
# 0      Jane Smith           68.73            15.44           83.71
# 1     Chris Jones           97.54             13.5           67.65
# 2  Emily Williams           86.60            15.46           71.73
# 3      Anna Moore           79.93             5.06           67.09
# 4     Beth Taylor           57.80             13.9           50.74
#
#   Extracurricular Activities  Final Score
# 0                        Low        72.58
# 1                       High        74.82
# 2                        Low        73.49
# 3                       High        62.87
# 4                       High        56.62

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df.head(5)
# Out:
#              name  attendance_(%) study_hours/week  previous_score  \
# 0      Jane Smith           68.73            15.44           83.71
# 1     Chris Jones           97.54             13.5           67.65
# 2  Emily Williams           86.60            15.46           71.73
# 3      Anna Moore           79.93             5.06           67.09
# 4     Beth Taylor           57.80             13.9           50.74
#
#   extracurricular_activities  final_score
# 0                        Low        72.58
# 1                       High        74.82
# 2                        Low        73.49
# 3                       High        62.87
# 4                       High        56.62

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   name                        736 non-null    object
#  1   attendance_(%)              736 non-null    float64
#  2   study_hours/week            736 non-null    object
#  3   previous_score              736 non-null    float64
#  4   extracurricular_activities  736 non-null    object
#  5   final_score                 736 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 34.6+ KB

# %%
df['study_hours/week'] = pd.to_numeric(df['study_hours/week'], errors='coerce', downcast='float')
print(df.isnull().sum())
# Out:
# name                          0
# attendance_(%)                0
# study_hours/week              3
# previous_score                0
# extracurricular_activities    0
# final_score                   0
# dtype: int64

# %%
null_entries = df[df['study_hours/week'].isnull()]
print(null_entries)
# Out:
#              name  attendance_(%)  study_hours/week  previous_score  \
# 398     Jane Gray           85.51               NaN           87.34
# 546      Alex Lee           71.29               NaN           75.98
# 647  Katie Carter           58.06               NaN           82.14
#
#     extracurricular_activities  final_score
# 398                        Low        80.24
# 546                       High        74.24
# 647                       High        73.58

# %%
df = df.dropna(subset=['study_hours/week'])

# %%
print(df.isnull().sum())
# Out:
# name                          0
# attendance_(%)                0
# study_hours/week              0
# previous_score                0
# extracurricular_activities    0
# final_score                   0
# dtype: int64

# %%
activity_mapping = {
    'Low': 0,
    'Moderate': 1,
    'High': 2
}
df['extracurricular_activities'] = df['extracurricular_activities'].map(activity_mapping)
df.head(10)
# Out:
#              name  attendance_(%)  study_hours/week  previous_score  \
# 0      Jane Smith           68.73         15.440000           83.71
# 1     Chris Jones           97.54         13.500000           67.65
# 2  Emily Williams           86.60         15.460000           71.73
# 3      Anna Moore           79.93          5.060000           67.09
# 4     Beth Taylor           57.80         13.900000           50.74
# 5   Michael Smith           57.80         16.790001           79.73
# 6    John Johnson           52.90         22.389999           55.44
# 7      Emma Jones           93.31         12.410000           41.34
# 8    David Taylor           80.06         10.960000           75.50
# 9      Mark Moore           85.40         12.490000           49.74
#
#    extracurricular_activities  final_score
# 0                           0        72.58
# 1                           2        74.82
# 2                           0        73.49
# 3                           2        62.87
# 4                           2        56.62
# 5                           1        70.24
# 6                           2        63.98
# 7                           1        61.05
# 8                           0        70.88
# 9                           2        63.22

# %%
df.describe()
# Out:
#        attendance_(%)  study_hours/week  previous_score  \
# count      733.000000        733.000000       733.00000
# mean        72.076276         15.510818        74.89719
# std         12.833310          2.622354        10.59302
# min         50.280000          5.060000        40.85000
# 25%         60.660000         13.510000        68.62000
# 50%         68.010000         15.340000        75.98000
# 75%         86.090000         17.230000        82.76000
# max         99.340000         27.320000        94.45000
#
#        extracurricular_activities  final_score
# count                  733.000000   733.000000
# mean                     0.956344    73.413042
# std                      0.737929     6.068034
# min                      0.000000    54.920000
# 25%                      0.000000    67.580000
# 50%                      1.000000    73.240000
# 75%                      2.000000    77.580000
# max                      2.000000    88.720000

# %%
df.head()
# Out:
#              name  attendance_(%)  study_hours/week  previous_score  \
# 0      Jane Smith           68.73             15.44           83.71
# 1     Chris Jones           97.54             13.50           67.65
# 2  Emily Williams           86.60             15.46           71.73
# 3      Anna Moore           79.93              5.06           67.09
# 4     Beth Taylor           57.80             13.90           50.74
#
#    extracurricular_activities  final_score
# 0                           0        72.58
# 1                           2        74.82
# 2                           0        73.49
# 3                           2        62.87
# 4                           2        56.62

# %%
df2 = df.drop('name', axis=1)

# %%
print(df2.dtypes)
# Out:
# attendance_(%)                float64
# study_hours/week              float32
# previous_score                float64
# extracurricular_activities      int64
# final_score                   float64
# dtype: object

# %%
sns.scatterplot(x="previous_score",y="final_score",data=df2)
# Out:
# <Axes: xlabel='previous_score', ylabel='final_score'>

# %% [markdown]
# The scatterplot between previous_score and final_score shows that they are somehow linearly realted to each other which means that the current performance of the students can be predicted on the basis of their previous performance.

# %%
sns.histplot(data=df, x='study_hours/week', bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Study Hours per Week')
plt.xlabel('Study Hours per Week')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above histogram one can easily identify that most of the students studied around 15 hours per week the current semester.

# %%
corr_matrix=df2.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,annot=True,fmt='.2f',cmap='coolwarm',linewidths=0.5)
plt.show()

# %% [markdown]
# From the analysis of heatmap, it was found that previous_score and attendance showed high correlation with final_score which indicated that the current performance of the students greatly rely on their recent performance and their frequency of classes attend.Students not attending the college study more than the students attending the college at their home.

# %%
df3 = df2.drop(['study_hours/week','extracurricular_activities'], axis=1)
df3.head(5)
# Out:
#    attendance_(%)  previous_score  final_score
# 0           68.73           83.71        72.58
# 1           97.54           67.65        74.82
# 2           86.60           71.73        73.49
# 3           79.93           67.09        62.87
# 4           57.80           50.74        56.62

# %%
fig,axes = plt.subplots(1,2,figsize=(10,8))

sns.boxplot(data=df3[['attendance_(%)','previous_score']],ax=axes[0])
axes[0].set_title("Boxplot of input features")

sns.boxplot(data=df3['final_score'],ax=axes[1])
axes[1].set_title("Boxplot of target feature")

plt.tight_layout()
plt.show()

# %%
Q1 = df3['previous_score'].quantile(0.25)
Q3 = df3['previous_score'].quantile(0.75)
IQR = Q3 - Q1
    
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
    
df3 = df3[(df['previous_score'] >= lower_bound) & (df3['previous_score'] <= upper_bound)]

# %%
fig,axes = plt.subplots(1,2,figsize=(10,8))

sns.boxplot(data=df3[['attendance_(%)','previous_score']],ax=axes[0])
axes[0].set_title("Boxplot of input features(Outlier removed)")

sns.boxplot(data=df3['final_score'],ax=axes[1])
axes[1].set_title("Boxplot of target feature")

plt.tight_layout()
plt.show()

# %%
X=df3[['attendance_(%)','previous_score']].values
y=df3['final_score'].values

# %%
print('Shape of feature matrix:\n',X.shape)
# Out:
# Shape of feature matrix:
#  (721, 2)

# %%
print('shape of target matrix:\n',y.shape)
# Out:
# shape of target matrix:
#  (721,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_train=scaler.fit_transform(X_train) 
X_test=scaler.transform(X_test)
